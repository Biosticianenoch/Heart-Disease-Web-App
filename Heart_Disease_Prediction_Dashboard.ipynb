# %% [markdown]
# Build Web App for Heart Disease with Streamlit

# %%
## Install required modules
# !pip install pyjanitor
# !pip install statsmodels
# Out:
# Collecting pyjanitor
#   Downloading pyjanitor-0.31.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: natsort in /usr/local/lib/python3.11/dist-packages (from pyjanitor) (8.4.0)
# Collecting pandas_flavor (from pyjanitor)
#   Downloading pandas_flavor-0.6.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.11/dist-packages (from pyjanitor) (1.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pyjanitor) (1.14.1)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.11/dist-packages (from pandas_flavor->pyjanitor) (2.2.2)
# Requirement already satisfied: xarray in /usr/local/lib/python3.11/dist-packages (from pandas_flavor->pyjanitor) (2025.1.2)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from scipy->pyjanitor) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.23->pandas_flavor->pyjanitor) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.23->pandas_flavor->pyjanitor) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.23->pandas_flavor->pyjanitor) (2025.1)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.11/dist-packages (from xarray->pandas_flavor->pyjanitor) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas_flavor->pyjanitor) (1.17.0)
# Downloading pyjanitor-0.31.0-py3-none-any.whl (215 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.4/215.4 kB 12.3 MB/s eta 0:00:00
# Downloading pandas_flavor-0.6.0-py3-none-any.whl (7.2 kB)
# Installing collected packages: pandas_flavor, pyjanitor
# Successfully installed pandas_flavor-0.6.0 pyjanitor-0.31.0
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.11/dist-packages (0.14.4)
# Requirement already satisfied: numpy<3,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (2.0.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (1.14.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)

# %%
## Importing the necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import janitor
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings("ignore")
from google.colab import drive
drive.mount('/content/drive')
import time
# Out:
# Mounted at /content/drive

# %%
## Load the dataset
file_path = '/content/drive/My Drive/heart.csv'
df = pd.read_csv(file_path).clean_names()

# %%
## View the first few observations of the dataset
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
# 5   0     2       1
# 6   3     1       0
# 7   1     3       0
# 8   0     3       0
# 9   2     2       0

# %%
## Assess the structure of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
## Checking for missing values
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
## Check for duplicates
df.duplicated().sum()
# Out:
# np.int64(723)

# %%
## Number of males and females whose heart data is stored in the dataset
df.sex.value_counts()
# Out:
# sex
# 1    713
# 0    312
# Name: count, dtype: int64

# %%
## Count of the number of males and females who have heart disease
df.sex[df.target==1].value_counts()
# Out:
# sex
# 1    300
# 0    226
# Name: count, dtype: int64

# %%
## Visualize your results
df.sex[df.target==1].value_counts().plot(kind='bar',figsize=(10,6),color=['green','blue'])
plt.title("Count of the number of males and females with heart disease")
plt.xticks(rotation=0);

# %%
## Contingency table
pd.crosstab(df.target,df.sex)
# Out:
# sex       0    1
# target
# 0        86  413
# 1       226  300

# %%
## Visualize the contingency table
pd.crosstab(df.target,df.sex).plot(kind='bar',figsize=(10,6),color=["lightblue","pink"])
plt.title("Frequency of Heart Disease vs Sex")
plt.xlabel("0= Heart Disease, 1= No disease")
plt.ylabel("Number of people with heart disease")
plt.legend(["Female","Male"])
plt.xticks(rotation=0);

# %%
## Building a Correlation Matrix
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.103240 -0.071966  0.271121  0.219823  0.121243
# sex      -0.103240  1.000000 -0.041119 -0.078974 -0.198258  0.027200
# cp       -0.071966 -0.041119  1.000000  0.038177 -0.081641  0.079294
# trestbps  0.271121 -0.078974  0.038177  1.000000  0.127977  0.181767
# chol      0.219823 -0.198258 -0.081641  0.127977  1.000000  0.026917
# fbs       0.121243  0.027200  0.079294  0.181767  0.026917  1.000000
# restecg  -0.132696 -0.055117  0.043581 -0.123794 -0.147410 -0.104051
# thalach  -0.390227 -0.049365  0.306839 -0.039264 -0.021772 -0.008866
# exang     0.088163  0.139157 -0.401513  0.061197  0.067382  0.049261
# oldpeak   0.208137  0.084687 -0.174733  0.187434  0.064880  0.010859
# slope    -0.169105 -0.026666  0.131633 -0.120445 -0.014248 -0.061902
# ca        0.271551  0.111729 -0.176206  0.104554  0.074259  0.137156
# thal      0.072297  0.198424 -0.163341  0.059276  0.100244 -0.042177
# target   -0.229324 -0.279501  0.434854 -0.138772 -0.099966 -0.041164
#
#            restecg   thalach     exang   oldpeak     slope        ca  \
# age      -0.132696 -0.390227  0.088163  0.208137 -0.169105  0.271551
# sex      -0.055117 -0.049365  0.139157  0.084687 -0.026666  0.111729
# cp        0.043581  0.306839 -0.401513 -0.174733  0.131633 -0.176206
# trestbps -0.123794 -0.039264  0.061197  0.187434 -0.120445  0.104554
# chol     -0.147410 -0.021772  0.067382  0.064880 -0.014248  0.074259
# fbs      -0.104051 -0.008866  0.049261  0.010859 -0.061902  0.137156
# restecg   1.000000  0.048411 -0.065606 -0.050114  0.086086 -0.078072
# thalach   0.048411  1.000000 -0.380281 -0.349796  0.395308 -0.207888
# exang    -0.065606 -0.380281  1.000000  0.310844 -0.267335  0.107849
# oldpeak  -0.050114 -0.349796  0.310844  1.000000 -0.575189  0.221816
# slope     0.086086  0.395308 -0.267335 -0.575189  1.000000 -0.073440
# ca       -0.078072 -0.207888  0.107849  0.221816 -0.073440  1.000000
# thal     -0.020504 -0.098068  0.197201  0.202672 -0.094090  0.149014
# target    0.134468  0.422895 -0.438029 -0.438441  0.345512 -0.382085
#
#               thal    target
# age       0.072297 -0.229324
# sex       0.198424 -0.279501
# cp       -0.163341  0.434854
# trestbps  0.059276 -0.138772
# chol      0.100244 -0.099966
# fbs      -0.042177 -0.041164
# restecg  -0.020504  0.134468
# thalach  -0.098068  0.422895
# exang     0.197201 -0.438029
# oldpeak   0.202672 -0.438441
# slope    -0.094090  0.345512
# ca        0.149014 -0.382085
# thal      1.000000 -0.337838
# target   -0.337838  1.000000

# %%
## Visualize the correlation matrix
cor_mat=df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(cor_mat,annot=True,cmap="coolwarm", fmt = ".2f")
plt.title("Correlation Matrix")
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# ## Machine Learning

# %%
## Standardization using the MinMax Scaling
from sklearn.preprocessing import MinMaxScaler
scal=MinMaxScaler()
feat=['age', 'trestbps', 'thalach' ,'oldpeak' , 'chol']
df[feat] = scal.fit_transform(df[feat])
df.head()
# Out:
#         age  sex  cp  trestbps      chol  fbs  restecg   thalach  exang  \
# 0  0.479167    1   0  0.292453  0.196347    0        1  0.740458      0
# 1  0.500000    1   0  0.433962  0.175799    1        0  0.641221      1
# 2  0.854167    1   0  0.481132  0.109589    0        1  0.412214      1
# 3  0.666667    1   0  0.509434  0.175799    0        1  0.687023      0
# 4  0.687500    0   0  0.415094  0.383562    1        1  0.267176      0
#
#     oldpeak  slope  ca  thal  target
# 0  0.161290      2   2     3       0
# 1  0.500000      0   0     3       0
# 2  0.419355      0   0     3       0
# 3  0.000000      2   1     3       0
# 4  0.306452      1   3     2       0

# %%
## Creating Features and Target variable
X=df.drop("target",axis=1).values
Y=df.target.values

# %%
## Splitting the data into train and test sets
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,random_state=42,test_size=0.2)

# %%
## Create a function for evaluating metrics
from sklearn.metrics import accuracy_score,recall_score,f1_score,precision_score,roc_auc_score,confusion_matrix

def evaluation(Y_test,Y_pred):
  acc=accuracy_score(Y_test,Y_pred)
  rcl=recall_score(Y_test,Y_pred)
  f1=f1_score(Y_test,Y_pred)


  metric_dict={'accuracy': round(acc,3),
               'recall': round(rcl,3),
               'F1 score': round(f1,3),

              }

  return print(metric_dict)

# %% [markdown]
# #### Fitting and Comparing different Models

# %%
## K-Nearest Neighbors
np.random.seed(42)
from sklearn.neighbors import KNeighborsClassifier
Knn_clf=  KNeighborsClassifier()
Knn_clf.fit(X_train,Y_train)
Knn_Y_pred=Knn_clf.predict(X_test)
Knn_score=Knn_clf.score(X_test,Y_test)
#print(Knn_score)
evaluation(Y_test,Knn_Y_pred)
# Out:
# {'accuracy': 0.859, 'recall': 0.883, 'F1 score': 0.863}

# %%
## Logistic Regression
np.random.seed(42)
from sklearn.linear_model import LogisticRegression
LR_clf=LogisticRegression()
LR_clf.fit(X_train,Y_train)
LR_Y_pred=LR_clf.predict(X_test)
LR_score=LR_clf.score(X_test,Y_test)
#print(LR_score)
evaluation(Y_test,LR_Y_pred)
# Out:
# {'accuracy': 0.8, 'recall': 0.874, 'F1 score': 0.814}

# %%
## Random Forest
np.random.seed(42)
from sklearn.ensemble import RandomForestClassifier
RF_clf=RandomForestClassifier(n_estimators=450)
RF_clf.fit(X_train,Y_train)
RF_score=RF_clf.score(X_test,Y_test)
RF_Y_pred=RF_clf.predict(X_test)
#print(RF_score)
evaluation(Y_test,RF_Y_pred)
# Out:
# {'accuracy': 0.985, 'recall': 0.971, 'F1 score': 0.985}

# %%
## Support Vector Machines
np.random.seed(42)
from sklearn.svm import SVC
SVC_clf=SVC()
SVC_clf.fit(X_train,Y_train)
SVC_score=SVC_clf.score(X_test,Y_test)
SVC_Y_pred=SVC_clf.predict(X_test)
#print(SVC_score)
evaluation(Y_test,SVC_Y_pred)
# Out:
# {'accuracy': 0.883, 'recall': 0.932, 'F1 score': 0.889}

# %%
## XGBOOST
from xgboost import XGBClassifier
XGB_clf=XGBClassifier()
XGB_clf.fit(X_train,Y_train)
XGB_score=XGB_clf.score(X_test,Y_test)
XGB_Y_pred=XGB_clf.predict(X_test)
#print(SVC_score)
evaluation(Y_test,XGB_Y_pred)
# Out:
# {'accuracy': 0.985, 'recall': 0.971, 'F1 score': 0.985}

# %% [markdown]
# ## Comparing the performance of different models

# %%
## Model comparison
model_comp = pd.DataFrame({'Model': ['Logistic Regression','Random Forest',
                    'K-Nearest Neighbour','Support Vector Machine',"XGBoost"], 'Accuracy': [LR_score*100,
                    RF_score*100,Knn_score*100,SVC_score*100,XGB_score*100]})
model_comp
# Out:
#                     Model   Accuracy
# 0     Logistic Regression  80.000000
# 1           Random Forest  98.536585
# 2     K-Nearest Neighbour  85.853659
# 3  Support Vector Machine  88.292683
# 4                 XGBoost  98.536585

# %% [markdown]
# # Model Tuning

# %%
## Tuning KNN
neighbors = range(1, 21) # 1 to 20

# Setup algorithm
knn = KNeighborsClassifier()

# Loop through different neighbors values
for i in neighbors:
    knn.set_params(n_neighbors = i) # set neighbors value

    # Fit the algorithm
    print(f"Accuracy with {i} no. of neighbors: {knn.fit(X_train, Y_train).score(X_test,Y_test)}%")
# Out:
# Accuracy with 1 no. of neighbors: 0.9853658536585366%
# Accuracy with 2 no. of neighbors: 0.975609756097561%
# Accuracy with 3 no. of neighbors: 0.9463414634146341%
# Accuracy with 4 no. of neighbors: 0.9024390243902439%
# Accuracy with 5 no. of neighbors: 0.8585365853658536%
# Accuracy with 6 no. of neighbors: 0.8536585365853658%
# Accuracy with 7 no. of neighbors: 0.8536585365853658%
# Accuracy with 8 no. of neighbors: 0.8439024390243902%
# Accuracy with 9 no. of neighbors: 0.848780487804878%
# Accuracy with 10 no. of neighbors: 0.8292682926829268%
# Accuracy with 11 no. of neighbors: 0.8146341463414634%
# Accuracy with 12 no. of neighbors: 0.8146341463414634%
# Accuracy with 13 no. of neighbors: 0.8%
# Accuracy with 14 no. of neighbors: 0.7853658536585366%
# Accuracy with 15 no. of neighbors: 0.8341463414634146%
# Accuracy with 16 no. of neighbors: 0.8341463414634146%
# Accuracy with 17 no. of neighbors: 0.8341463414634146%
# Accuracy with 18 no. of neighbors: 0.8682926829268293%
# Accuracy with 19 no. of neighbors: 0.8585365853658536%
# Accuracy with 20 no. of neighbors: 0.8341463414634146%

# %%
## Fitting the KNN with the best numner of neighbors
np.random.seed(42)
from sklearn.neighbors import KNeighborsClassifier
Knn_clf=  KNeighborsClassifier(n_neighbors=1)
Knn_clf.fit(X_train,Y_train)
Knn_Y_pred=Knn_clf.predict(X_test)
Knn_score=Knn_clf.score(X_test,Y_test)
evaluation(Y_test,Knn_Y_pred)
# Out:
# {'accuracy': 0.985, 'recall': 0.971, 'F1 score': 0.985}

# %%
## Hyper parameter tuning SVC using GridSearchCV
from sklearn.model_selection import GridSearchCV

# defining parameter range
param_grid = {'C': [0.1, 1,2, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf','linear']}

gs_clf = GridSearchCV(SVC(), param_grid,cv=5, refit = True, verbose = 3)

# fitting the model for grid search
gs_clf.fit(X_train, Y_train)

print(gs_clf.best_params_)

print(f"Accuracy score:{gs_clf.score(X_test,Y_test)}%")
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.902 total time=   0.0s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.872 total time=   0.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.872 total time=   0.0s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.921 total time=   0.0s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.835 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.860 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.860 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.884 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.829 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.780 total time=   0.0s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.878 total time=   0.0s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.848 total time=   0.0s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.860 total time=   0.0s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.848 total time=   0.0s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.793 total time=   0.0s
# [CV 1/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.860 total time=   0.0s
# [CV 2/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.860 total time=   0.0s
# [CV 3/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.884 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.829 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.780 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.841 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.829 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.835 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.835 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.768 total time=   0.0s
# [CV 1/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.860 total time=   0.0s
# [CV 2/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.860 total time=   0.0s
# [CV 3/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.884 total time=   0.0s
# [CV 4/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.829 total time=   0.0s
# [CV 5/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.780 total time=   0.0s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.512 total time=   0.0s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.512 total time=   0.0s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.518 total time=   0.0s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.518 total time=   0.0s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.518 total time=   0.0s
# [CV 1/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.860 total time=   0.0s
# [CV 2/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.860 total time=   0.0s
# [CV 3/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.884 total time=   0.0s
# [CV 4/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.829 total time=   0.0s
# [CV 5/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.780 total time=   0.0s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.512 total time=   0.0s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.512 total time=   0.0s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.518 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.518 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.518 total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.860 total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.860 total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.884 total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.829 total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.780 total time=   0.0s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.957 total time=   0.0s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.927 total time=   0.0s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.927 total time=   0.0s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.939 total time=   0.0s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.890 total time=   0.0s
# [CV 1/5] END .......C=1, gamma=1, kernel=linear;, score=0.841 total time=   0.0s
# [CV 2/5] END .......C=1, gamma=1, kernel=linear;, score=0.866 total time=   0.0s
# [CV 3/5] END .......C=1, gamma=1, kernel=linear;, score=0.878 total time=   0.0s
# [CV 4/5] END .......C=1, gamma=1, kernel=linear;, score=0.860 total time=   0.0s
# [CV 5/5] END .......C=1, gamma=1, kernel=linear;, score=0.811 total time=   0.0s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.896 total time=   0.0s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.878 total time=   0.0s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.902 total time=   0.0s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.878 total time=   0.0s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.835 total time=   0.0s
# [CV 1/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.841 total time=   0.0s
# [CV 2/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.866 total time=   0.0s
# [CV 3/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.878 total time=   0.0s
# [CV 4/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.860 total time=   0.0s
# [CV 5/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.811 total time=   0.0s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.860 total time=   0.0s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.835 total time=   0.0s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.866 total time=   0.0s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.829 total time=   0.0s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.780 total time=   0.0s
# [CV 1/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.841 total time=   0.0s
# [CV 2/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.866 total time=   0.0s
# [CV 3/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.878 total time=   0.0s
# [CV 4/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.860 total time=   0.0s
# [CV 5/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.811 total time=   0.0s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.835 total time=   0.0s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.829 total time=   0.0s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.841 total time=   0.0s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.823 total time=   0.0s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.787 total time=   0.0s
# [CV 1/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.841 total time=   0.0s
# [CV 2/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.866 total time=   0.0s
# [CV 3/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.878 total time=   0.0s
# [CV 4/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.860 total time=   0.0s
# [CV 5/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.811 total time=   0.0s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.512 total time=   0.0s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.512 total time=   0.0s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.518 total time=   0.0s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.518 total time=   0.0s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.518 total time=   0.0s
# [CV 1/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.841 total time=   0.0s
# [CV 2/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.866 total time=   0.0s
# [CV 3/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.878 total time=   0.0s
# [CV 4/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.860 total time=   0.0s
# [CV 5/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.811 total time=   0.0s
# [CV 1/5] END ..........C=2, gamma=1, kernel=rbf;, score=0.982 total time=   0.0s
# [CV 2/5] END ..........C=2, gamma=1, kernel=rbf;, score=0.933 total time=   0.0s
# [CV 3/5] END ..........C=2, gamma=1, kernel=rbf;, score=0.951 total time=   0.0s
# [CV 4/5] END ..........C=2, gamma=1, kernel=rbf;, score=0.957 total time=   0.0s
# [CV 5/5] END ..........C=2, gamma=1, kernel=rbf;, score=0.902 total time=   0.0s
# [CV 1/5] END .......C=2, gamma=1, kernel=linear;, score=0.829 total time=   0.0s
# [CV 2/5] END .......C=2, gamma=1, kernel=linear;, score=0.848 total time=   0.0s
# [CV 3/5] END .......C=2, gamma=1, kernel=linear;, score=0.866 total time=   0.0s
# [CV 4/5] END .......C=2, gamma=1, kernel=linear;, score=0.884 total time=   0.0s
# [CV 5/5] END .......C=2, gamma=1, kernel=linear;, score=0.811 total time=   0.0s
# [CV 1/5] END ........C=2, gamma=0.1, kernel=rbf;, score=0.927 total time=   0.0s
# [CV 2/5] END ........C=2, gamma=0.1, kernel=rbf;, score=0.915 total time=   0.0s
# [CV 3/5] END ........C=2, gamma=0.1, kernel=rbf;, score=0.896 total time=   0.0s
# [CV 4/5] END ........C=2, gamma=0.1, kernel=rbf;, score=0.915 total time=   0.0s
# [CV 5/5] END ........C=2, gamma=0.1, kernel=rbf;, score=0.848 total time=   0.0s
# [CV 1/5] END .....C=2, gamma=0.1, kernel=linear;, score=0.829 total time=   0.0s
# [CV 2/5] END .....C=2, gamma=0.1, kernel=linear;, score=0.848 total time=   0.0s
# [CV 3/5] END .....C=2, gamma=0.1, kernel=linear;, score=0.866 total time=   0.0s
# [CV 4/5] END .....C=2, gamma=0.1, kernel=linear;, score=0.884 total time=   0.0s
# [CV 5/5] END .....C=2, gamma=0.1, kernel=linear;, score=0.811 total time=   0.0s
# [CV 1/5] END .......C=2, gamma=0.01, kernel=rbf;, score=0.860 total time=   0.0s
# [CV 2/5] END .......C=2, gamma=0.01, kernel=rbf;, score=0.848 total time=   0.0s
# [CV 3/5] END .......C=2, gamma=0.01, kernel=rbf;, score=0.878 total time=   0.0s
# [CV 4/5] END .......C=2, gamma=0.01, kernel=rbf;, score=0.848 total time=   0.0s
# [CV 5/5] END .......C=2, gamma=0.01, kernel=rbf;, score=0.768 total time=   0.0s
# [CV 1/5] END ....C=2, gamma=0.01, kernel=linear;, score=0.829 total time=   0.0s
# [CV 2/5] END ....C=2, gamma=0.01, kernel=linear;, score=0.848 total time=   0.0s
# [CV 3/5] END ....C=2, gamma=0.01, kernel=linear;, score=0.866 total time=   0.0s
# [CV 4/5] END ....C=2, gamma=0.01, kernel=linear;, score=0.884 total time=   0.0s
# [CV 5/5] END ....C=2, gamma=0.01, kernel=linear;, score=0.811 total time=   0.0s
# [CV 1/5] END ......C=2, gamma=0.001, kernel=rbf;, score=0.854 total time=   0.0s
# [CV 2/5] END ......C=2, gamma=0.001, kernel=rbf;, score=0.841 total time=   0.0s
# [CV 3/5] END ......C=2, gamma=0.001, kernel=rbf;, score=0.835 total time=   0.0s
# [CV 4/5] END ......C=2, gamma=0.001, kernel=rbf;, score=0.835 total time=   0.0s
# [CV 5/5] END ......C=2, gamma=0.001, kernel=rbf;, score=0.780 total time=   0.0s
# [CV 1/5] END ...C=2, gamma=0.001, kernel=linear;, score=0.829 total time=   0.0s
# [CV 2/5] END ...C=2, gamma=0.001, kernel=linear;, score=0.848 total time=   0.0s
# [CV 3/5] END ...C=2, gamma=0.001, kernel=linear;, score=0.866 total time=   0.0s
# [CV 4/5] END ...C=2, gamma=0.001, kernel=linear;, score=0.884 total time=   0.0s
# [CV 5/5] END ...C=2, gamma=0.001, kernel=linear;, score=0.811 total time=   0.0s
# [CV 1/5] END .....C=2, gamma=0.0001, kernel=rbf;, score=0.512 total time=   0.0s
# [CV 2/5] END .....C=2, gamma=0.0001, kernel=rbf;, score=0.512 total time=   0.0s
# [CV 3/5] END .....C=2, gamma=0.0001, kernel=rbf;, score=0.518 total time=   0.0s
# [CV 4/5] END .....C=2, gamma=0.0001, kernel=rbf;, score=0.518 total time=   0.0s
# [CV 5/5] END .....C=2, gamma=0.0001, kernel=rbf;, score=0.518 total time=   0.0s
# [CV 1/5] END ..C=2, gamma=0.0001, kernel=linear;, score=0.829 total time=   0.0s
# [CV 2/5] END ..C=2, gamma=0.0001, kernel=linear;, score=0.848 total time=   0.0s
# [CV 3/5] END ..C=2, gamma=0.0001, kernel=linear;, score=0.866 total time=   0.0s
# [CV 4/5] END ..C=2, gamma=0.0001, kernel=linear;, score=0.884 total time=   0.0s
# [CV 5/5] END ..C=2, gamma=0.0001, kernel=linear;, score=0.811 total time=   0.0s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.933 total time=   0.0s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.982 total time=   0.0s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.994 total time=   0.0s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.945 total time=   0.0s
# [CV 1/5] END ......C=10, gamma=1, kernel=linear;, score=0.829 total time=   0.0s
# [CV 2/5] END ......C=10, gamma=1, kernel=linear;, score=0.841 total time=   0.0s
# [CV 3/5] END ......C=10, gamma=1, kernel=linear;, score=0.860 total time=   0.0s
# [CV 4/5] END ......C=10, gamma=1, kernel=linear;, score=0.884 total time=   0.0s
# [CV 5/5] END ......C=10, gamma=1, kernel=linear;, score=0.811 total time=   0.0s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.933 total time=   0.0s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.921 total time=   0.0s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.933 total time=   0.0s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.939 total time=   0.0s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.878 total time=   0.0s
# [CV 1/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.829 total time=   0.0s
# [CV 2/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.841 total time=   0.0s
# [CV 3/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.860 total time=   0.0s
# [CV 4/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.884 total time=   0.0s
# [CV 5/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.811 total time=   0.0s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.878 total time=   0.0s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.884 total time=   0.0s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.896 total time=   0.0s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.860 total time=   0.0s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.829 total time=   0.0s
# [CV 1/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.829 total time=   0.0s
# [CV 2/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.841 total time=   0.0s
# [CV 3/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.860 total time=   0.0s
# [CV 4/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.884 total time=   0.0s
# [CV 5/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.811 total time=   0.0s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.872 total time=   0.0s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.817 total time=   0.0s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.854 total time=   0.0s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.829 total time=   0.0s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.780 total time=   0.0s
# [CV 1/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.829 total time=   0.0s
# [CV 2/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.841 total time=   0.0s
# [CV 3/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.860 total time=   0.0s
# [CV 4/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.884 total time=   0.0s
# [CV 5/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.811 total time=   0.0s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.835 total time=   0.0s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.829 total time=   0.0s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.841 total time=   0.0s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.823 total time=   0.0s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.787 total time=   0.0s
# [CV 1/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.829 total time=   0.0s
# [CV 2/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.841 total time=   0.0s
# [CV 3/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.860 total time=   0.0s
# [CV 4/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.884 total time=   0.0s
# [CV 5/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.811 total time=   0.0s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.957 total time=   0.0s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.994 total time=   0.0s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.945 total time=   0.0s
# [CV 1/5] END .....C=100, gamma=1, kernel=linear;, score=0.835 total time=   0.2s
# [CV 2/5] END .....C=100, gamma=1, kernel=linear;, score=0.841 total time=   0.1s
# [CV 3/5] END .....C=100, gamma=1, kernel=linear;, score=0.866 total time=   0.3s
# [CV 4/5] END .....C=100, gamma=1, kernel=linear;, score=0.884 total time=   0.4s
# [CV 5/5] END .....C=100, gamma=1, kernel=linear;, score=0.811 total time=   0.2s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.970 total time=   0.0s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.933 total time=   0.0s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.970 total time=   0.0s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.963 total time=   0.0s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.909 total time=   0.0s
# [CV 1/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.835 total time=   0.3s
# [CV 2/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.841 total time=   0.2s
# [CV 3/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.866 total time=   0.2s
# [CV 4/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.884 total time=   0.4s
# [CV 5/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.811 total time=   0.2s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.890 total time=   0.0s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.896 total time=   0.0s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.933 total time=   0.0s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.902 total time=   0.0s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.848 total time=   0.0s
# [CV 1/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.835 total time=   0.3s
# [CV 2/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.841 total time=   0.2s
# [CV 3/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.866 total time=   0.3s
# [CV 4/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.884 total time=   0.4s
# [CV 5/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.811 total time=   0.2s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.866 total time=   0.0s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.854 total time=   0.0s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.872 total time=   0.0s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.848 total time=   0.0s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.799 total time=   0.0s
# [CV 1/5] END .C=100, gamma=0.001, kernel=linear;, score=0.835 total time=   0.2s
# [CV 2/5] END .C=100, gamma=0.001, kernel=linear;, score=0.841 total time=   0.1s
# [CV 3/5] END .C=100, gamma=0.001, kernel=linear;, score=0.866 total time=   0.1s
# [CV 4/5] END .C=100, gamma=0.001, kernel=linear;, score=0.884 total time=   0.2s
# [CV 5/5] END .C=100, gamma=0.001, kernel=linear;, score=0.811 total time=   0.1s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.866 total time=   0.0s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.817 total time=   0.0s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.854 total time=   0.0s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.829 total time=   0.0s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.780 total time=   0.0s
# [CV 1/5] END C=100, gamma=0.0001, kernel=linear;, score=0.835 total time=   0.2s
# [CV 2/5] END C=100, gamma=0.0001, kernel=linear;, score=0.841 total time=   0.1s
# [CV 3/5] END C=100, gamma=0.0001, kernel=linear;, score=0.866 total time=   0.1s
# [CV 4/5] END C=100, gamma=0.0001, kernel=linear;, score=0.884 total time=   0.2s
# [CV 5/5] END C=100, gamma=0.0001, kernel=linear;, score=0.811 total time=   0.1s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.957 total time=   0.0s
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.994 total time=   0.0s
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.945 total time=   0.0s
# [CV 1/5] END ....C=1000, gamma=1, kernel=linear;, score=0.835 total time=   0.9s
# [CV 2/5] END ....C=1000, gamma=1, kernel=linear;, score=0.841 total time=   1.3s
# [CV 3/5] END ....C=1000, gamma=1, kernel=linear;, score=0.866 total time=   1.4s
# [CV 4/5] END ....C=1000, gamma=1, kernel=linear;, score=0.884 total time=   2.7s
# [CV 5/5] END ....C=1000, gamma=1, kernel=linear;, score=0.805 total time=   1.6s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.963 total time=   0.0s
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.994 total time=   0.0s
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.927 total time=   0.0s
# [CV 1/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.835 total time=   1.3s
# [CV 2/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.841 total time=   2.3s
# [CV 3/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.866 total time=   1.9s
# [CV 4/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.884 total time=   2.7s
# [CV 5/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.805 total time=   1.6s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.933 total time=   0.0s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.902 total time=   0.0s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.915 total time=   0.0s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.939 total time=   0.0s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.860 total time=   0.0s
# [CV 1/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.835 total time=   1.0s
# [CV 2/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.841 total time=   1.9s
# [CV 3/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.866 total time=   2.1s
# [CV 4/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.884 total time=   4.5s
# [CV 5/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.805 total time=   1.6s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.854 total time=   0.0s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.884 total time=   0.0s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.902 total time=   0.0s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.884 total time=   0.0s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.817 total time=   0.0s
# [CV 1/5] END C=1000, gamma=0.001, kernel=linear;, score=0.835 total time=   1.0s
# [CV 2/5] END C=1000, gamma=0.001, kernel=linear;, score=0.841 total time=   1.2s
# [CV 3/5] END C=1000, gamma=0.001, kernel=linear;, score=0.866 total time=   1.5s
# [CV 4/5] END C=1000, gamma=0.001, kernel=linear;, score=0.884 total time=   2.7s
# [CV 5/5] END C=1000, gamma=0.001, kernel=linear;, score=0.805 total time=   1.7s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.854 total time=   0.0s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.854 total time=   0.0s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.866 total time=   0.0s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.835 total time=   0.0s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.805 total time=   0.0s
# [CV 1/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.835 total time=   1.8s
# [CV 2/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.841 total time=   2.0s
# [CV 3/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.866 total time=   1.4s
# [CV 4/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.884 total time=   2.7s
# [CV 5/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.805 total time=   1.6s
# {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
# Accuracy score:0.9707317073170731%

# %%
## Hyper parameter tuning KNN using GridSearchCV
knn_grid={'n_neighbors': np.arange(1,30,1),
          'leaf_size': np.arange(1,50,1)}

gs_knn=GridSearchCV(KNeighborsClassifier(),param_grid=knn_grid,cv=5,verbose=True)

gs_knn.fit(X_train, Y_train)

gs_knn.best_params_

print(f"Accuracy score:{gs_knn.score(X_test,Y_test)*100}%")
# Out:
# Fitting 5 folds for each of 1421 candidates, totalling 7105 fits
# Accuracy score:98.53658536585365%

# %%
xgb = XGBClassifier(learning_rate=0.01, n_estimators=25, max_depth=15,gamma=0.6, subsample=0.52,colsample_bytree=0.6,seed=27,
                    reg_lambda=2, booster='dart', colsample_bylevel=0.6, colsample_bynode=0.5)

xgb.fit(X_train,Y_train)
xgb_score=XGB_clf.score(X_test,Y_test)
xgb_Y_pred=XGB_clf.predict(X_test)
#print(SVC_score)
evaluation(Y_test,xgb_Y_pred)
# Out:
# {'accuracy': 0.985, 'recall': 0.971, 'F1 score': 0.985}

# %% [markdown]
# ## Comparing Models after hyperparameter tuning

# %%
model_comp = pd.DataFrame({'Model': ['Logistic Regression','Random Forest',
                    'K-Nearest Neighbour','Support Vector Machine','Extreme Gradient Boost'], 'Accuracy': [LR_score*100,
                    RF2_acc_score*100,Knn_score*100,SVC_score*100, XGB_score*100]})
model_comp
# Out:
#                     Model   Accuracy
# 0     Logistic Regression  80.000000
# 1           Random Forest  83.414634
# 2     K-Nearest Neighbour  98.536585
# 3  Support Vector Machine  88.292683
# 4  Extreme Gradient Boost  98.536585

# %%
print(" Best evaluation parameters achieved with KNN:")
evaluation(Y_test, xgb_Y_pred)
# Out:
#  Best evaluation parameters achieved with KNN:
# {'accuracy': 0.985, 'recall': 0.971, 'F1 score': 0.985}

# %% [markdown]
# # Visualization of the Models Results

# %%
final_metrics={'Accuracy': xgb.score(X_test,Y_test),
                   'Precision': precision_score(Y_test,xgb_Y_pred),
                   'Recall': recall_score(Y_test,xgb_Y_pred),
                   'F1': f1_score(Y_test,xgb_Y_pred),
                   'AUC': roc_auc_score(Y_test,xgb_Y_pred)}

metrics=pd.DataFrame(final_metrics,index=[0])

metrics.T.plot.bar(title='Final metric evaluation',legend=False);

# %% [markdown]
# # Create the confusion matrix of the best model

# %%
from sklearn.metrics import confusion_matrix

fig,ax=plt.subplots()
ax=sns.heatmap(confusion_matrix(Y_test,xgb_Y_pred),annot=True,cbar=True);

# %% [markdown]
# #Let's save our model using pickle

# %%
## Lets save our model using pickle
import pickle as pkl
pkl.dump(xgb,open("final_model.p","wb"))

# %% [markdown]
# #Import streamlit,pyngrok, and ngrok modules

# %%
import sklearn
sklearn_version = sklearn.__version__
print(sklearn_version)
# !pip install streamlit
# !pip install pyngrok===4.1.1
from pyngrok import ngrok
# Out:
# 1.6.1
# Collecting streamlit
#   Downloading streamlit-1.43.2-py2.py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (11.1.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.29.3)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (4.12.2)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.11/dist-packages (from streamlit) (3.1.44)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (1.31.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2025.1.31)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.23.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.43.2-py2.py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 89.1 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 95.1 MB/s eta 0:00:00
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 6.4 MB/s eta 0:00:00
# Installing collected packages: watchdog, pydeck, streamlit
# Successfully installed pydeck-0.9.1 streamlit-1.43.2 watchdog-6.0.0
# Collecting pyngrok===4.1.1
#   Downloading pyngrok-4.1.1.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from pyngrok===4.1.1) (1.0.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from pyngrok===4.1.1) (6.0.2)
# Building wheels for collected packages: pyngrok
#   Building wheel for pyngrok (setup.py) ... done
#   Created wheel for pyngrok: filename=pyngrok-4.1.1-py3-none-any.whl size=15964 sha256=6dbd728cb5665284681329430b01fa47f9adb35c4bca23276bc19ff0e5bffbcb
#   Stored in directory: /root/.cache/pip/wheels/f4/e2/28/275496a22cb15fb495458aed2b164b4ccaa10e2f44188fb0b9
# Successfully built pyngrok
# Installing collected packages: pyngrok
# Successfully installed pyngrok-4.1.1

# %% [markdown]
# #Write a file for creating web app

# %%
# %%writefile healthy-heart-app.py
import streamlit as st
import base64
import sklearn
import numpy as np
import pickle as pkl
from sklearn.preprocessing import MinMaxScaler
scal=MinMaxScaler()
#Load the saved model
model=pkl.load(open("final_model.p","rb"))
st.set_page_config(page_title="Heart Disease Prediction Dashboard",page_icon="⚕️",layout="centered",initial_sidebar_state="expanded")



%%writefile healthy-heart-app.py
import streamlit as st
import base64
import sklearn
import numpy as np
import pickle as pkl
from sklearn.preprocessing import MinMaxScaler
scal=MinMaxScaler()
#Load the saved model
model=pkl.load(open("final_model.p","rb"))





st.set_page_config(page_title="Heart Disease Prediction Dashboard",page_icon="⚕️",layout="centered",initial_sidebar_state="expanded")



def preprocess(age,sex,cp,trestbps,restecg,chol,fbs,thalach,exang,oldpeak,slope,ca,thal ):


    # Pre-processing user input
    if sex=="male":
        sex=1
    else: sex=0


    if cp=="Typical angina":
        cp=0
    elif cp=="Atypical angina":
        cp=1
    elif cp=="Non-anginal pain":
        cp=2
    elif cp=="Asymptomatic":
        cp=2

    if exang=="Yes":
        exang=1
    elif exang=="No":
        exang=0

    if fbs=="Yes":
        fbs=1
    elif fbs=="No":
        fbs=0

    if slope=="Upsloping: better heart rate with excercise(uncommon)":
        slope=0
    elif slope=="Flatsloping: minimal change(typical healthy heart)":
          slope=1
    elif slope=="Downsloping: signs of unhealthy heart":
        slope=2

    if thal=="fixed defect: used to be defect but ok now":
        thal=6
    elif thal=="reversable defect: no proper blood movement when excercising":
        thal=7
    elif thal=="normal":
        thal=2.31

    if restecg=="Nothing to note":
        restecg=0
    elif restecg=="ST-T Wave abnormality":
        restecg=1
    elif restecg=="Possible or definite left ventricular hypertrophy":
        restecg=2


    user_input=[age,sex,cp,trestbps,restecg,chol,fbs,thalach,exang,oldpeak,slope,ca,thal]
    user_input=np.array(user_input)
    user_input=user_input.reshape(1,-1)
    user_input=scal.fit_transform(user_input)
    prediction = model.predict(user_input)

    return prediction




    # front end elements of the web page
html_temp = """
    <div style ="background-color:pink;padding:13px">
    <h1 style ="color:black;text-align:center;">Heart Disease Prediction Dashboard</h1>
    </div>
    """

# display the front end aspect
st.markdown(html_temp, unsafe_allow_html = True)
st.subheader('by Enock Bereka')

# following lines create boxes in which user can enter data required to make prediction
age=st.selectbox ("Age",range(1,121,1))
sex = st.radio("Select Gender: ", ('male', 'female'))
cp = st.selectbox('Chest Pain Type',("Typical angina","Atypical angina","Non-anginal pain","Asymptomatic"))
trestbps=st.selectbox('Resting Blood Sugar',range(1,500,1))
restecg=st.selectbox('Resting Electrocardiographic Results',("Nothing to note","ST-T Wave abnormality","Possible or definite left ventricular hypertrophy"))
chol=st.selectbox('Serum Cholestoral in mg/dl',range(1,1000,1))
fbs=st.radio("Fasting Blood Sugar higher than 120 mg/dl", ['Yes','No'])
thalach=st.selectbox('Maximum Heart Rate Achieved',range(1,300,1))
exang=st.selectbox('Exercise Induced Angina',["Yes","No"])
oldpeak=st.number_input('Oldpeak')
slope = st.selectbox('Heart Rate Slope',("Upsloping: better heart rate with excercise(uncommon)","Flatsloping: minimal change(typical healthy heart)","Downsloping: signs of unhealthy heart"))
ca=st.selectbox('Number of Major Vessels Colored by Flourosopy',range(0,5,1))
thal=st.selectbox('Thalium Stress Result',range(1,8,1))



#user_input=preprocess(sex,cp,exang, fbs, slope, thal )
pred=preprocess(age,sex,cp,trestbps,restecg,chol,fbs,thalach,exang,oldpeak,slope,ca,thal)




if st.button("Predict"):
  if pred[0] == 0:
    st.error('Warning! You have high risk of getting a heart attack!')

  else:
    st.success('You have lower risk of getting a heart disease!')





st.sidebar.subheader("About App")

st.sidebar.info("This web app is helps you to find out whether you are at a risk of developing a heart disease.")
st.sidebar.info("Enter the required fields and click on the 'Predict' button to check whether you have a healthy heart")
st.sidebar.info("Don't forget to rate this app")



feedback = st.sidebar.slider('How much would you rate this app?',min_value=0,max_value=5,step=1)

if feedback:
  st.header("Thank you for rating the app!")
  st.info("Caution: This is just a prediction and not doctoral advice. Kindly see a doctor if you feel the symptoms persist.")
# Out:
# Writing healthy-heart-app.py
